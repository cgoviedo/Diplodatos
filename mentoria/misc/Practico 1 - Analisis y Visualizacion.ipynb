# %% [markdown]
# ### Universidad Nacional de Córdoba - Facultad de Matemática, Astronomía, Física y Computación
#
# ### Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones 2021
# Búsqueda y Recomendación para Textos Legales
#
# Mentor: Jorge E. Pérez Villella
#
# # Práctico Análisis y Visualización
#
# Integrantes:

# %% [markdown]
# ### Objetivos:
#
# * Generar un corpus con todos los documentos.
#
# * Dividir el corpus en tokens, graficar el histograma de frecuencia de palabras demostrando la ley Zipf.
#
# * Analizar palabras más frecuentes y menos frecuentes. Seleccionar 5 documentos de cada fuero y realizar el mismo análisis. ¿Se repiten las palabras?
#
# * Hacer lo mismo con n-gramas.
#
# * Visualizar la frecuencia de palabras en una nube de palabras.
#
# * Elaborar una breve conclusión de lo encontrado
#
# Fecha de Entrega: 6 de junio de 2021

# %% [markdown]
# # Generar un corpus con todos los documentos

# %%
#!conda install -y -c anaconda spacy

# %%
#!python -m spacy download es_core_news_sm

# %%
import spacy
from spacy.lang.es.examples import sentences
import glob
import os
import pandas as pd 
import shutil

# %%
root_path = "Documentos"

directories = [x[0] for x in os.walk(root_path)]

directories.pop(0)

for directory in directories:
    print (directory)
# Out:
# Documentos/MENORES
# Documentos/PENAL
# Documentos/FAMILIA
# Documentos/LABORAL

# %%
def generate_corpus_df(directories):
    
    
    
   
    corpus = []

    for directory in directories:
      
        file_list = glob.glob(os.path.join(os.getcwd(), directory, "*.txt"))


        for file_path in file_list:
            with open(file_path) as f_input:
                corpus.append([f_input.read() , directory])

    return pd.DataFrame(corpus, columns=["text", "classifier"] )

# %%
corpus_df = generate_corpus_df(directories)

# %%
corpus_df[:10]
# Out:
#                                                 text          classifier
# 0  DATOS DE LA CAUSA\nSede: Ciudad de Córdoba. \n...  Documentos/MENORES
# 1  Unívoco:18900  Fecha: 04/04/2016\n Materia Niñ...  Documentos/MENORES
# 2  DATOS DE LA CAUSA\nSede: Ciudad de Córdoba. \n...  Documentos/MENORES
# 3  13/03/2013\nJuzgado de la Niñez, Juventud y Vi...  Documentos/MENORES
# 4  Los  autos  caratulados: ”A.,  A.  -  Denuncia...  Documentos/MENORES
# 5  Juzg. de Niñez, Adolescencia y Violencia Famil...  Documentos/MENORES
# 6  RIO CUARTO, 11/05/2018. Por evacuada la vista ...  Documentos/MENORES
# 7  AUTO INTERLOCUTORIO NÚMERO: dieciséis (16)\nCó...  Documentos/MENORES
# 8  “Córdoba, 30 de mayo de 2018. Por recibido. Té...  Documentos/MENORES
# 9  DATOS DE LA CAUSA\nSede: Ciudad de Córdoba.\nD...  Documentos/MENORES

# %%
def generate_corpus_file(directory, corpus_file_name): 
    
    outfilename = os.path.join(os.getcwd(), directory , corpus_file_name )
    input_files = os.path.join(os.getcwd(), directory , '*.txt' )
    
    with open(outfilename, 'wb') as outfile:
        for filename in glob.glob(input_files):
            if filename == outfilename:
                # don't want to copy the output into the output
                continue
            with open(filename, 'rb') as readfile:
                shutil.copyfileobj(readfile, outfile)

# %%
# Generamos el corpus de cada fuero en el archivo corpust.txt. Hacemos esto puesto que es muchos menos 
# costoso que pasar a un unico string los valores del data frame

corpus_file_name = "corpus.txt"
for directory in directories:
    generate_corpus_file(directory, corpus_file_name)

# %%
def generate_agregate_df_corpus(directories, corpus_file_name): 
    
    agregate_df_corpus = pd.DataFrame()
        
    for directory in directories: 
        
        corpus_file = os.path.join(os.getcwd(), directory , corpus_file_name ) 
        print(corpus_file)
        with open(corpus_file, 'r') as file:
            data = file.read().replace('\n', ' ')
            print(data[:10])
            agregate_df_corpus.append({'text' : data, 'tag' : directory } , ignore_index = True)
            print ("Se agrego")
    
    return agregate_df_corpus

# %%
def generate_agregate_df_corpus_2(directories, corpus_file_name): 
    
    agregate_df_corpus = pd.DataFrame(columns=['text', 'tag'])
        
    for directory in directories: 
        
        corpus_file = os.path.join(os.getcwd(), directory , corpus_file_name ) 
        data = open(corpus_file, 'r').read()
        agregate_df_corpus = agregate_df_corpus.append({'text' : data, 'tag' : directory } , ignore_index = True)
        
    return agregate_df_corpus

# %%
agregate_df_corpus = generate_agregate_df_corpus_2(directories ,corpus_file_name )

# %%
agregate_df_corpus[:]
# Out:
#                                                 text                 tag
# 0  DATOS DE LA CAUSA\nSede: Ciudad de Córdoba. \n...  Documentos/MENORES
# 1  SALA PENAL - TRIBUNAL SUPERIOR\n\nProtocolo de...    Documentos/PENAL
# 2  AUTO NÚMERO: sesenta y seis \nCórdoba, cinco d...  Documentos/FAMILIA
# 3  SALA LABORAL - TRIBUNAL SUPERIOR\n\nProtocolo ...  Documentos/LABORAL

# %%
agregate_df_corpus[:1].text.values
# Out:
# array(['DATOS DE LA CAUSA\nSede: Ciudad de Córdoba. \nDependencia: Juzgado de Niñez, Adolescencia, Violencia Familiar y de Género de Quinta Nominación.\nAutos: “M., M. C. – Denuncia por violencia familiar”.\nResolución: Auto interlocutorio n.° 3.\nFecha: 15/5/2018.\nJueza: Carla Olocco de Otto.\nAnálisis documental: María Verónica Ruiu (redactora) y Susana María Squizzato (tutora).\n\nSÍNTESIS DE LA CAUSA\nLa jueza de violencia rechazó el recurso de reposición interpuesto por la parte denunciada, en contra del proveído que ordenó poner en conocimiento del fiscal de instrucción, la posible comisión de un ilícito penal consistente en el incumplimiento de las medidas de protección dispuestas. \n \nSUMARIOS:\n\nVIOLENCIA FAMILIAR .ORDEN PÚBLICO. INTERÉS SOCIAL.\nLas disposiciones legales contenidas en la Ley de violencia familiar son de orden público e interés social. Tienen por objeto la prevención, detección temprana, atención y erradicación de la violencia familiar y de la violencia hacia las mujeres por cuestiones de género en la modalidad doméstica (art. 1 de la  Ley n.°  9283, reformada por Ley n.° 10400). \n\nVIOLENCIA FAMILIAR. Medidas de protección. Remisión de los antecedentes al fiscal de instrucción ante posible comisión de ilícito penal. \nAnte el posible incumplimiento de una orden judicial emanada del juez de violencia familiar, si la víctima no ha formulado una nueva denuncia ante la Unidad Judicial, ni cuenta en su poder con un dispositivo SALVA, la remisión de copias al fiscal de instrucción que por turno corresponda reviste el carácter de imperativo e insoslayable. El anoticiamiento formulado al fuero penal por parte del juez de violencia familiar, se efectúa solo a los fines de que ese órgano  –en virtud de la competencia que detenta– sea quien valore la posible comisión de un ilícito penal; extremo que no importa acusación ni imputación penal del denunciado. \n\nVIOLENCIA FAMILIAR: Remisión de los antecedentes al Fiscal de instrucción ante posible comisión de ilícito penal. Derecho de defensa.\nNo se vislumbra en qué forma o manera puede violarse el derecho de defensa que le asiste al denunciado al ponerse en conocimiento del fiscal de instrucción la posible comisión de un ilícito penal. Ello, por cuanto el acceso a la justicia se le ha garantizado y se ha efectivizado a lo largo del proceso, habiendo sido escuchado en forma directa y personal –acompañado de patrocinio letrado– por el tribunal en la oportunidad procesal que la normativa legal establece (art. 22 de la Ley n.° 9283). Ni la ley foral ni sus concordantes exigen la previa escucha o traslado de ley a la contraparte, con anterioridad al dictado de una providencia como la que se ataca.\nAuto interlocutorio n.º 3, del 15/5/2018.\n\nCórdoba, quince de Mayo del año dos mil dieciocho. Y VISTOS: Los autos caratulados\n\n“M., M. C., DENUNCIA POR VIOLENCIA FAMILIAR” traídos a despacho a los fines de resolver el recurso de reposición interpuesto a fs. 123/125, por el Sr. M. C. M., acompañado de su letrado patrocinante, Dr. A. R., en contra de la providencia de fecha nueve de marzo del año dos mil dieciocho, obrante a fs. 114 de autos, que reza: “Córdoba, 09/03/2018….A mérito de las manifestaciones vertidas a fs. 104 y el emplazamiento formulado a fs. 82, póngase en conocimiento del Sr. Fiscal de Instrucción que por turno corresponda la posible comisión de un ilícito penal (art. 239) por parte del Sr. M. C. M., a cuyo fin ofíciese con la remisión de copias pertinentes y útiles….” Firmado: Dra. C. O. de O., Jueza  Dra. A. del V. P.: Prosecretaria Letrada. DE LOS QUE RESULTA: 1) Contra dicha providencia se alza el quejoso deduciendo recurso de reposición. Los puntos de agravios se sintetizan en el siguiente compendio: 1.a) En primer término, niega y considera absolutamente falsos los hechos denunciados por la Sra. S. V., con relación al incumplimiento de las medidas de protección dispuestas, toda vez que el impugnante no podría haber incurrido en los mismos ya q ...
#       dtype=object)

# %% [markdown]
# # Dividir el corpus en tokens, graficar el histograma de frecuencia de palabras demostrando la ley Zipf.

# %%
spacy_nlp = spacy.load("es_core_news_sm")

# %% [markdown]
# # no funciona, consume mucha memoria
# def generate_corpus_by_tag(df, tag):
#
#     corpus = corpus_df[corpus_df['classifier'] == classifier ].text.to_list()
#
#     return corpus

# %% [markdown]
# # no funciona, consume mucha memoria
# spacy_nlp.max_length = 3000000
# for directory in directories:
#     print (f"Generando corpus de {directory}")
#     corpus = "".join(corpus_df[corpus_df['classifier'] == classifier ].text.to_list())
#     corpus_doc = spacy_nlp(corpus)

# %%
spacy_nlp.max_length = 7000000
doc = spacy_nlp(agregate_df_corpus[agregate_df_corpus['tag'] == 'Documentos/MENORES'].text[0])

# %%
words = [token.text
         for token in doc
         if not token.is_stop and not token.is_punct]

# %%
from collections import Counter
word_freq = Counter(words)

# %%
common_words = word_freq.most_common(10)

# %%
common_words
# Out:
# [(' ', 11660),
#  ('y', 10122),
#  ('a', 8780),
#  ('\n\n', 2170),
#  ('fs', 2010),
#  ('niño', 1666),
#  ('\n', 1410),
#  ('o', 1158),
#  ('Sra.', 1156),
#  ('art', 1106)]

# %%
doc_penal = spacy_nlp(agregate_df_corpus[agregate_df_corpus['tag'] == 'Documentos/PENAL'].text[1])

# %%
words = [token.text
         for token in doc
         if not token.is_stop and not token.is_punct]

# %%
common_words = word_freq.most_common(10)
