# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/christianoviedo/Downloads/runs-2.csv')

df.head()
# Out:
#             Start Time Duration                            Run ID  Name  \
# 0  2022-02-10 15:43:18    19.4h  9c8153947bca4a4d9b8ffd300bc17ad9   NaN
# 1  2022-02-10 15:42:24    19.1h  58fe5e4bf383409ebada7c583ed95180   NaN
# 2  2022-02-10 15:04:36     2.8h  386538e95e7544639b8f1868e09bbe33   NaN
# 3  2022-02-09 16:32:27     1.1h  82f2740afffb4bb4aad4d6e622c70505   NaN
# 4  2022-02-08 11:09:55     2.2h  c0249644d26341489ad82b0589e6dd95   NaN
#
#   Source Type                                        Source Name  \
# 0       LOCAL  /Users/christianoviedo/Desktop/ciencia_datos/d...
# 1       LOCAL  /Users/christianoviedo/Desktop/ciencia_datos/d...
# 2       LOCAL  /Users/christianoviedo/Desktop/ciencia_datos/d...
# 3       LOCAL  /Users/christianoviedo/Desktop/ciencia_datos/d...
# 4       LOCAL  /Users/christianoviedo/Desktop/ciencia_datos/d...
#
#               User    Status  batch_size  dropout  ...     lr  \
# 0  christianoviedo  FINISHED       128.0      0.3  ...  0.001
# ...

# %%
df.to_csv('/Users/christianoviedo/Downloads/result.csv', index=False)

# %%
df['test_loss'] = df['test_loss'].round(decimals=5)

# %%
df['test_bacc'] = df['test_bacc'].round(decimals=5)

# %%
df['train_loss'] = df['train_loss'].round(decimals=5)

# %%
df['validation_bacc'] = df['validation_bacc'].round(decimals=5)

# %%
df['validation_loss'] = df['validation_loss'].round(decimals=5)

# %%
df
# Out:
#              Start Time Duration                            Run ID  Name  \
# 0   2022-02-10 15:43:18    19.4h  9c8153947bca4a4d9b8ffd300bc17ad9   NaN
# 1   2022-02-10 15:42:24    19.1h  58fe5e4bf383409ebada7c583ed95180   NaN
# 2   2022-02-10 15:04:36     2.8h  386538e95e7544639b8f1868e09bbe33   NaN
# 3   2022-02-09 16:32:27     1.1h  82f2740afffb4bb4aad4d6e622c70505   NaN
# 4   2022-02-08 11:09:55     2.2h  c0249644d26341489ad82b0589e6dd95   NaN
# 5   2022-02-07 14:46:26     6.4h  a97c5bc848b549ee90d444d986f905a1   NaN
# 6   2022-02-07 14:45:03     6.0h  a6bcda3de1d74b4c8ec30596247d1fd9   NaN
# 7   2022-02-07 13:36:04     3.2h  8c2709ec6e2a4eaf8acec99db7f33993   NaN
# 8   2022-02-07 13:33:32     4.1h  519b0577f2484cb783407d55a2f67f58   NaN
# 9   2022-02-07 12:00:58     2.4h  8c7284b067e0490ab03f6753ec83c9fc   NaN
# 10  2022-02-07 11:14:21     2.5h  5423c32785a0488fb872b1103ad54b25   NaN
# 11  2022-02-07 10:13:57     2.4h  ee2876b5414c4bc7ad472498228e9c27   NaN
# ...

# %%
df.to_csv('/Users/christianoviedo/Downloads/result.csv', index=False)

# %%
df.columns
# Out:
# Index(['Start Time', 'Duration', 'Run ID', 'Name', 'Source Type',
#        'Source Name', 'User', 'Status', 'batch_size', 'dropout', 'embeddings',
#        'embeddings_size', 'epochs', 'filters_count', 'filters_length',
#        'freeze_embedings', 'hidden_layers', 'lr', 'lstm_hidden_size',
#        'lstm_num_layers', 'model_type', 'random-buffer-size', 'test_bacc',
#        'test_loss', 'train_loss', 'validation_bacc', 'validation_loss'],
#       dtype='object')
